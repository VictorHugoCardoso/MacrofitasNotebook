# %%
#sensor = 'LANDSAT8';
sensor = 'SENTINEL';
dataInicial = '2012-01-01'; #ano,mes,dia
dataFinal = '2020-01-01';
max_nuvens = 5

'''
saoFranciscoFalso,saoFranciscoVerdadeiro,ocoi,

bracos = ['aguaVerde','apipu','bangu','belaVista','doisIrmaos','guabiroba','guacu','itacora220',
              'itavo220','jacutinga','maya','moinho','moledo220','naranjito','ocoi','onca','passoCue',
              'petronius','porvenir','rioBranco','salamanca','sangaAlegre','saoCristovao','saoFranciscoFalso',
              'saoFranciscoVerdadeiro','saoJorge','saoLuiz','saoVicenteChico','saoVicenteSaoJoao','solMaio220',
              'taquapetinga','tigre220','tresIrmas','vinitu','xororo','costanera','dosHermanas',
              'itabo','limoy','pikyry','piraPyta','tatiYupi','brillante','carapa','gasory','itambey','pozuelo','santaTeresa','corpoCentral'] # 49
'''
bracos = ['saoFranciscoFalso','saoFranciscoVerdadeiro']

# %%
import ee
import psycopg2
import time

print("Iniciando conexão com EE...");
ee.Initialize();
print("Conectado!");
# Out:
# Iniciando conexão com EE...
# Conectado!

# %%
satelite = -1
if sensor == 'SENTINEL':
    satelite = 1
    bandas = ['B8','B4','B11']
    scale = 10
    clouds = 'CLOUDY_PIXEL_PERCENTAGE'
    dataset = 'COPERNICUS/S2'
    
    escolha = 0
    print 'Sentinel escolhido!'
else:
    satelite = 0
    bandas = ['B5','B4','B6']
    scale = 30
    clouds = 'CLOUD_COVER'
    dataset = 'LANDSAT/LC08/C01/T1_SR'
    
    escolha = 1
    print 'Landsat escolhido!'
# Out:
# Sentinel escolhido!

# %%
dataset = ee.ImageCollection(dataset) \
            .filter(ee.Filter.date(dataInicial, dataFinal)) \
            .filterBounds(ee.Algorithms.GeometryConstructors.MultiPoint([[-54.32822528851034, -24.660395975306944],[-54.49576679241659, -25.30643825264147]])) \
            .filter(ee.Filter.lessThanOrEquals(clouds,80));
            
projection = ee.Image(dataset.first()).select('B4').projection();

# %%
def mapCloudscore(image):
    if(satelite):
        pq = image.select('QA60');
        return ee.Image(0).where(pq.gt(0),1).rename(ee.List(['cloudMask']));
    else:
        pq = image.select('pixel_qa');
        return ee.Image(0).where(pq.neq(324).And(pq.neq(322)),1).rename(ee.List(['cloudMask']));

# %%
def mapNDVI(image):
    image = ee.Image(image);
    ndvi = image.normalizedDifference([bandas[0],bandas[1]]).rename(['ndvi']);
    return ndvi;

# %%
def mapMacrofitas(image,projection):
    image = ee.Image(image);
    ndvi = image.normalizedDifference([bandas[0],bandas[1]]);
    soma = ndvi.reproject(projection).reduceResolution(ee.Reducer.sum());
    porcentagem = soma.divide(ndvi).multiply(100).round();
    clippedNdvi = ndvi.updateMask(ndvi.where(porcentagem.lte(99),0));
    output = ee.Image(0).where(clippedNdvi.gte(0.2).And(image.select(bandas[2]).gt(0.06)),1);
    macrofitas = output.updateMask(output).rename(['macrofitas']).reproject(projection);

    return macrofitas;

# %%
def getDataStr(image):
    image = ee.Image(image);
    eedate = ee.Date(image.get('system:time_start'))
    dia = ee.Number(eedate.get('day')).format()
    mes = ee.Number(eedate.get('month')).format()
    ano = ee.Number(eedate.get('year')).format()
    data = ano.cat('-').cat(mes).cat('-').cat(dia)
    return data

# %%
def mapper(image):

    image = ee.Image(image);
    cloudscore = mapCloudscore(image);   
    macrofitas = ee.Image(mapMacrofitas(image,projection));
    ndvi = ee.Image(mapNDVI(image));
    data = getDataStr(image);

    return image.addBands(macrofitas).addBands(cloudscore).addBands(ndvi).set('data',data);

# %%
collection = dataset.map(mapper);
tamanho = ee.ImageCollection(collection).toList(1000).length().getInfo()
collection = ee.ImageCollection(collection).toList(tamanho);
print str(tamanho)+' imagens\n'
# Out:
# 283 imagens

# %%
for i in range(tamanho):
    image = ee.Image(collection.get(i))
    id_imagem = image.id().getInfo()
    data = image.get('data').getInfo()
    
    start_time = time.time()
    bracosInseridos = 0
    print("*================================================================*")
    print "("+str(i+1)+")", id_imagem
    print("*================================================================*")
    
    for i in range(0, len(bracos)):
        braco = bracos[i]
        regiao = ee.Feature(ee.FeatureCollection("users/odraitaipu/bracos/"+braco).union().first()).set('nome',braco).geometry()
        
        intersecao = image.geometry().intersection(regiao,ee.ErrorMargin(1));
        porcentagem_intersecao = ee.Number((intersecao.area().multiply(100)).divide(regiao.area())).getInfo()
        
        print braco
        if porcentagem_intersecao > 10:
            
            meanClouds = ee.Number(image.select('cloudMask').reduceRegion(ee.Reducer.mean(), regiao, scale, None, None, True).get('cloudMask')).multiply(100).getInfo()
            
            if meanClouds <= max_nuvens:
                
                if i < 35:
                    local_segmento = 'me'
                elif i >= 35 and i != 48:
                    local_segmento = 'md'
                elif i == 48:
                    local_segmento = 'cc'

                shapeMacrofita = image.select('macrofitas').reduceToVectors(ee.Reducer.countEvery(),regiao,None,'polygon',True,'macrofitas',None,None,True).union(1).geometry()
                meanNDVI = image.select('ndvi').reduceRegion(ee.Reducer.mean(), shapeMacrofita, scale, None, None, True).get('ndvi')

                areaRegiao = regiao.area();
                areaMacrofitas = shapeMacrofita.area(ee.ErrorMargin(1));
                macrofitas_porcentagem = (areaMacrofitas.multiply(100)).divide(areaRegiao);

                shapeMacrofita = shapeMacrofita.getInfo()
                areaMacrofitas = areaMacrofitas.getInfo()
                macrofitas_porcentagem = macrofitas_porcentagem.getInfo()
                meanNDVI = meanNDVI.getInfo()

                import json
                geoJson = shapeMacrofita
                geoJson["crs"] = {"type": "name","properties": {"name": "EPSG:4326"}}
                geoJsonStr = json.dumps(shapeMacrofita)

                host = '179.106.229.170'
                port = '5432'
                dbname = 'postgis'
                usuario = 'postgres'
                senha = 'postgres'

                comando = "INSERT INTO macrofitas(id,the_geom,data_passagem,sensor,media_ndvi,nome_segmento,local_segmento,area_macrofitas_m2,porcentagem_macrofitas,porcentagem_nuvens,porcentagem_intersecao,id_imagem)" + \
                          "VALUES(DEFAULT,ST_GeomFromGeoJSON('"+geoJsonStr+"'),'"+str(data)+"','"+sensor+"',"+str(meanNDVI)+",'"+braco+"', '"+local_segmento+"',"+str(areaMacrofitas)+","+str(macrofitas_porcentagem)+ \
                          ","+str(meanClouds)+","+str(porcentagem_intersecao)+",'"+id_imagem+"');"

                con = None
                try:
                    con = psycopg2.connect("host='"+host+"' port='"+port+"' dbname='"+dbname+"' user='"+usuario+"' password='"+senha+"'")   
                    cur = con.cursor()
                    cur.execute(comando)
                    con.commit()
                    print 'Inserido!\n'

                    bracosInseridos += 1
                except psycopg2.DatabaseError, e:
                    if con:
                        con.rollback()
                    print 'Error %s' % e
                    bracosInseridos -= 1
                finally:   
                    if con: 
                        con.close()
            else:
                print "Pulando região, "+ str(meanClouds) +"% de cobertura de nuvens\n"
        else:
            print "Pulando região, não está contida na cena\n"
                        
    elapsed_time = time.time() - start_time
    print 'Varredura de imagem finalizada. Inseridos '+str(bracosInseridos)+' bracos em '+ str(elapsed_time) + ' segundos'
    print "("+str((100*i)/tamanho)+"%)"
    print "------------------------------------------------------------------\n\n"
    
print "\n\n/------------------------------------------------------------------------------------------------------------/"
print "Procedimento completo!"
print "/------------------------------------------------------------------------------------------------------------/"
# Out:
# *================================================================*
# (1) 20150909T134916_20150909T134918_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0774860183398 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (2) 20150909T134916_20150909T134918_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 13.7372055046% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.570062434673 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (3) 20150909T134916_20161014T075239_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0708735664686 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (4) 20150909T134916_20161014T075239_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 13.7372055046% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.567150465647 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (5) 20150929T134916_20161031T042046_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0770543972651 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (6) 20150929T134916_20161031T042046_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 88.8749317929% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.199091716607 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (7) 20151128T134947_20151128T214005_T21JYJ
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 88.1305707345% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.186924231052 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (8) 20151208T134922_20151208T134916_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.148567799727 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (9) 20151208T134922_20151208T134916_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 48.1797105051% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.479088715712 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (10) 20151208T134922_20170529T101555_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0607721328735 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (11) 20151208T134922_20170529T101555_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 48.1797105051% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.539197099209 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (12) 20151208T134952_20151208T191025_T21JYH
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0688803990682 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (13) 20151208T134952_20151208T191025_T21JYJ
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 35.3347936546% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.184497769674 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (14) 20151228T134922_20151228T134916_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 89.8863560634% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.213400916258 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (15) 20151228T134952_20151228T190230_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 89.8863560634% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.181937567393 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (16) 20160107T134912_20160107T134915_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.073802848657 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (17) 20160107T134912_20160107T134915_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 24.9192460502% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.624339433511 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (18) 20160107T134951_20160107T191733_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0728819330533 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (19) 20160107T134951_20160107T191733_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 24.9192460502% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.519683134556 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (20) 20160117T134032_20160117T134100_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0644071857135 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (21) 20160117T134032_20160117T134100_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.2033765316 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (22) 20160117T135146_20160117T185938_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0722139994303 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (23) 20160117T135146_20160117T185938_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.2099908034 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (24) 20160206T134912_20160206T134913_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0740865190824 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (25) 20160206T134912_20160206T134913_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 0.986309548219 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (26) 20160206T134913_20160206T201158_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0733229319255 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (27) 20160206T134913_20160206T201158_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.0429975152 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (28) 20160307T134911_20160307T210119_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0754157503446 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (29) 20160307T134911_20160307T210119_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.12497668266 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (30) 20160307T134912_20160307T134911_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0657194654147 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (31) 20160307T134912_20160307T134911_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.14757173459 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (32) 20160317T134032_20160317T134639_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0735365311305 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (33) 20160317T134032_20160317T134639_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.13666838408 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (34) 20160317T134639_20160317T200622_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0755061666171 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (35) 20160317T134639_20160317T200622_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.17764553229 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (36) 20160406T134912_20160406T134913_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0727093815804 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (37) 20160406T134912_20160406T134913_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.081237336 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (38) 20160406T134913_20160406T200257_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0793993671735 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (39) 20160406T134913_20160406T200257_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.03863348166 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (40) 20160416T134042_20160416T134433_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0617764671644 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (41) 20160416T134042_20160416T134433_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.06585284869 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (42) 20160416T134433_20160416T200510_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.051303768158 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (43) 20160416T134433_20160416T200510_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.09118150075 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (44) 20160516T134922_20160516T134922_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.160937980811 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (45) 20160516T134922_20160516T134922_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 74.7863388847% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 71.2938571713% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.195552285512 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (46) 20160516T134922_20160516T200343_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0660680135091 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (47) 20160516T134922_20160516T200343_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 74.7863388847% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 71.2938571713% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.185364202658 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (48) 20160605T134921_20160605T200533_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0770456512769 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (49) 20160605T134922_20160605T134921_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.07179210186 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (50) 20160615T134212_20160615T134542_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0849064509074 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (51) 20160615T134212_20160615T134542_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.23997733593 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (52) 20160615T134542_20160615T200506_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0780542333921 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (53) 20160615T134542_20160615T200506_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.25748921633 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (54) 20160725T134257_20160725T200552_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0696360667547 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (55) 20160725T134257_20160725T200552_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 74.3090539942% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 46.2170215589% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.202159468333 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (56) 20160804T134920_20160804T201942_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0757168332736 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (57) 20160804T134920_20160804T201942_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 64.0297581579% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 38.219128602% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.198826134205 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (58) 20160824T134922_20160824T134918_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0754131515821 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (59) 20160824T134922_20160824T134918_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 0.963042298953 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (60) 20160824T134922_20160824T201800_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.078184167544 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (61) 20160824T134922_20160824T201800_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 0.997813316186 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (62) 20160913T134912_20160913T134913_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.03318956693 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (63) 20160913T134912_20160913T201937_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.01783233484 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (64) 20160923T134202_20160923T134625_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0772216995557 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (65) 20160923T134202_20160923T134625_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.16632714669 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (66) 20160923T134202_20160923T200506_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0752485672633 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (67) 20160923T134202_20160923T200506_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.25820866426 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (68) 20161013T134212_20161013T134206_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0746071338654 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (69) 20161013T134212_20161013T183907_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0720184167226 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (70) 20161112T134212_20161112T134719_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0706508477529 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (71) 20161112T134212_20161112T134719_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.1652673165 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (72) 20161112T134212_20161112T200414_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0819341182709 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (73) 20161112T134212_20161112T200414_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.194558183352 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (74) 20161122T134912_20161122T134915_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0785112301509 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (75) 20161122T134912_20161122T134915_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 0.879535468419 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (76) 20161122T134912_20161122T200333_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0746320168177 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (77) 20161122T134912_20161122T200333_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 0.997475000223 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (78) 20161202T134212_20161202T134208_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0846286177635 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (79) 20161202T134212_20161202T134208_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.189721918106 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (80) 20161202T134212_20161202T170831_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0774423996607 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (81) 20161202T134212_20161202T170831_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.193473680814 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (82) 20161212T134212_20161212T134546_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0760917345683 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (83) 20161212T134212_20161212T134546_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Pulando região, 7.94925273297% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.822971951962 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (84) 20161222T134202_20161222T134254_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0755578160286 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (85) 20161222T134202_20161222T134254_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 27.2819697099% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 42.444840392% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.202936903636 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (86) 20170111T134141_20170111T134139_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0846887310346 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (87) 20170111T134141_20170111T134139_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 45.447059352% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.198553367456 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (88) 20170220T134201_20170220T134204_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0730392336845 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (89) 20170220T134201_20170220T134204_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.194005048275 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (90) 20170302T134201_20170302T134204_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0795812169711 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (91) 20170322T134201_20170322T134203_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0898642500242 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (92) 20170322T134201_20170322T134203_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 80.39638325% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 15.6230221684% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.194097113609 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (93) 20170501T134211_20170501T134853_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0711893161138 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (94) 20170501T134211_20170501T134853_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.54846126636 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (95) 20170610T134211_20170610T134913_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0601915001869 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (96) 20170610T134211_20170610T134913_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.07811968327 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (97) 20170630T134211_20170630T134900_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Pulando região, 62.5776005976% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.729535667102 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (98) 20170720T134211_20170720T134833_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0744463523229 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (99) 20170720T134211_20170720T134833_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.20466425021 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (100) 20170804T134209_20170804T134404_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0654404163361 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (101) 20170804T134209_20170804T134404_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.17964510123 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (102) 20170829T134211_20170829T134822_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.073553999265 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (103) 20170829T134211_20170829T134822_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.26781089703 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (104) 20170918T134211_20170918T134207_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.058732632796 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (105) 20170918T134211_20170918T134207_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.22012688319 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (106) 20171003T134159_20171003T134557_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0744152347247 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (107) 20171003T134159_20171003T134557_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.23228334983 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (108) 20171008T134211_20171008T134654_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0747915188471 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (109) 20171023T134159_20171023T134157_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0778087496758 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (110) 20171023T134159_20171023T134157_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.29215808312 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (111) 20171028T134211_20171028T134210_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# ...
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.196605201562 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (176) 20180809T134209_20180809T134321_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 41.413881467% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 71.7862502058% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.181349782149 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (177) 20180814T134211_20180814T134210_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0712395826976 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (178) 20180814T134211_20180814T134210_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.0967492183 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (179) 20180819T134209_20180819T134652_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0775075674057 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (180) 20180819T134209_20180819T134652_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 100.0% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.607627785206 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (181) 20180824T134211_20180824T134209_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.069461564223 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (182) 20180824T134211_20180824T134209_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 94.0876382383% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 84.8820943088% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.186340947946 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (183) 20180829T134159_20180829T134610_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0670198162397 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (184) 20180829T134159_20180829T134610_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.14810380141 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (185) 20180908T134159_20180908T134346_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0693793018659 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (186) 20180908T134159_20180908T134346_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.21574303706 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (187) 20180918T134159_20180918T134202_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0706397692362 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (188) 20180918T134159_20180918T134202_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.12465031942 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (189) 20180923T134211_20180923T134539_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0752880016963 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (190) 20180923T134211_20180923T134539_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.11321411928 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (191) 20180928T134209_20180928T134458_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0727786024412 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (192) 20180928T134209_20180928T134458_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Pulando região, 6.96106379241% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.833063952128 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (193) 20181028T134209_20181028T134208_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0639800667763 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (194) 20181028T134209_20181028T134208_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.27046523492 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (195) 20181102T134211_20181102T134207_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0639296650887 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (196) 20181102T134211_20181102T134207_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 31.23871843% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 25.5542516571% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.190558151404 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (197) 20181107T134209_20181107T134212_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.080766415596 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (198) 20181107T134209_20181107T134212_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.2055957516 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (199) 20181117T134209_20181117T134838_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0764362176259 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (200) 20181117T134209_20181117T134838_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.20184673468 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (201) 20181122T134201_20181122T134203_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0747741500537 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (202) 20181122T134201_20181122T134203_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Pulando região, 22.9682978496% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.736049067974 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (203) 20181127T134209_20181127T134206_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.16278529962 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (204) 20181202T134201_20181202T134202_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0763554016749 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (205) 20181202T134201_20181202T134202_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 58.9751559015% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 1 bracos em 0.733536481857 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (206) 20181207T134209_20181207T134404_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0741568962733 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (207) 20181207T134209_20181207T134404_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 80.0182506025% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 100.0% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.209128801028 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (208) 20181212T134201_20181212T134202_T21JYN
# *================================================================*
# saoFranciscoFalso
# Pulando região, 13.1871935353% de cobertura de nuvens
#
# saoFranciscoVerdadeiro
# Pulando região, 10.2824717819% de cobertura de nuvens
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.186162634691 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (209) 20181217T134209_20181217T134205_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0761649330457 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (210) 20181217T134209_20181217T134205_T21JYN
# *================================================================*
# saoFranciscoFalso
# Inserido!
#
# saoFranciscoVerdadeiro
# Inserido!
#
# Varredura de imagem finalizada. Inseridos 2 bracos em 1.19947285255 minutos
# ------------------------------------------------------------------
#
#
# *================================================================*
# (211) 20181227T134209_20181227T134616_T21JYM
# *================================================================*
# saoFranciscoFalso
# Pulando região, não está contida na cena
#
# saoFranciscoVerdadeiro
# Pulando região, não está contida na cena
#
# Varredura de imagem finalizada. Inseridos 0 bracos em 0.0781387805939 minutos
# ------------------------------------------------------------------
